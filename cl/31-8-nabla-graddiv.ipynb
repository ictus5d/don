# %%
# https://pastel.archives-ouvertes.fr/file/index/docid/46557/filename/tel-00005612.pdf
# %display latex

# %%
nab=var("nabla",latex_name=r'\mathcal{\nabla.f}')

# %%
f(x,y) = x^2
div= derivative( f )
nabla=div;show(f);show(nab,nabla)
# Out:
# (x, y) |--> x^2
# nabla (x, y) |--> 2*x

# %%
E.<x,y> = EuclideanSpace()
v = E.vector_field(1/x,0, name='v')
v.display()
# Out:
# v = 1/x e_x

# %%
from sage.manifolds.operators import *
s= div(v);s.display()
# Out:
# div(v): E^2 --> R
#    (x, y) |--> -1/x^2

# %%
show(nab,nabla)
# Out:
# nabla (x, y) |--> 2*x

# %%
plot_vector_field((y,(cos(x)-2) * sin(x)),
                  (x,-pi,pi), (y,-pi,pi))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
u, v = var('u v')
f = exp(-(u^2 + v^2))
plot_vector_field(f.gradient(), 
(u,-2,2), (v,-2,2), color='blue')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
u, v = var('u v')
f = exp(-(u^2 + v^2))
plot_vector_field(-f.gradient(), 
(u,-2,2), (v,-2,2), color='blue')
# Out:
# Graphics object consisting of 1 graphics primitive
