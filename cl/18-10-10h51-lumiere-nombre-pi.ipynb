# %% [markdown]
# ###### Fréquence = rayon
#
# $\omega = \pi f 2 $ circonférence = $c=\pi r 2$
#
# Donc $\omega$ a toujours une valeur fondamentale
#
# 314159265.3 x 2 * 1 équivalente à L(inductance) C(capacitance).

# %%
# %display latex

# %%
w=2*n(pi)*1;show("omega = ",w)
# Out:
# 'omega = ' 6.28318530717959

# %%
u=1/n(pi)*360E-8;show("u = ",u)
# Out:
# 'u = ' 1.14591559026165e-6

# %%
s=1/(n(pi)*360E+8);show("s = ",s)
# Out:
# 's = ' 8.84194128288307e-12

# %%
vv=1/sqrt(u*s);show("w =",vv)
# Out:
# 'w =' 3.14159265358979e8

# %%
fr=vv/(2*n(pi));round(fr*2)
# Out:
# 100000000

# %% [markdown]
# La fréquence de résonance est le rayon et $c$ est la circonférence

# %%
q=n(pi)*4E-7;show(q);c=299792458
p=1/(q*c*c);show(p);show(p)
# Out:
# 1.25663706143592e-6
# 8.85418781762039e-12
# 8.85418781762039e-12

# %%
show("iq = ",1/q," ip =" ,1/p)
# Out:
# 'iq = ' 795774.715459477 ' ip =' 1.12940906675815e11

# %%
show("cc = ",1/q*1/p)
# Out:
# 'cc = ' 8.98755178736818e16

# %%
round(10-0.1,2)
# Out:
# 9.9

# %%
f=10;t=0.1;c
# Out:
# 299792458

# %%
gamma=round(c*t);show("gamma 1/10 de c =",gamma)
# Out:
# 'gamma 1/10 de c =' 29979246

# %%
Gama=round(c*f);show("10 fois c = ",Gama)
# Out:
# '10 fois c = ' 2997924580

# %%
ir=u*s;ir
# Out:
# 1.01321183642338e-17

# %% [markdown]
# L'impédance est l'inverse de l'indice de réfraction au carré

# %%
ri=u/s;ri
# Out:
# 129600.000000000

# %% [markdown]
# $\pi$ est pondéré, chaque décimale à un poids bien déterminé :1/10=0.1 par 4/100 pour la seconde décimale :0.04 et la trente deux ième décimales un zéro ? Quel en est le poids ?

# %%
n(pi,digits=33)
# Out:
# 3.14159265358979323846264338327950

# %%
1/314159265358979323846264338327950
# Out:
# 1/314159265358979323846264338327950

# %%
314159265358979323846264338327950
# Out:
# 314159265358979323846264338327950

# %%
n(pi,digits=32)
# Out:
# 3.1415926535897932384626433832795

# %% [markdown]
# Ce n'est pas surprenant que la décimale 32 soit un zéro $2^5=32$. Les anciens chinois le savaient, dans le dao, ils l'expriment, c'est une quinte ! Carré = seconde, cube=tierce, quarte 4 quinte 5. Ca n'a rien de quantique, mais tout de quintique !
#
# Les probabilités c'est du pipo, même $\pi$ est déterminé, il ne change pas à travers les millénaires.

# %%
2^5
# Out:
# 32

# %%
2^3,3^2
# Out:
# (8, 9)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
299792458*0.82
# Out:
# 2.45829815560000e8

# %%
299792458*0.84
# Out:
# 2.51825664720000e8

# %%
299792458-251825674
# Out:
# 47966784

# %%
299792458/1.047
# Out:
# 2.86334725883477e8

# %%
299792458-
