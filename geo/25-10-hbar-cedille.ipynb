# %%
# %display latex

# %% [markdown]
# ##### An de grâce 2018, Jeudi 25 octobre 10h36.

# %% [markdown]
# Dear Donald,
#
# Reading your Physical interpretation of the Planck’s constant based on the Maxwell theory, I was surprised seeing the figure 1 :
#
# ![fig1.png](attachment:fig1.png)
#
# Because I am working on an analog figure but not an ellipse rather a circle (with different meaning I expose now).
#
# Though my motivation is different I am wondering if there is not a possible connection between both ?
#
# Your equation (2) $\frac {p^2}{a^2}+\frac{q^2}{b^2}=1$, can be reduced (or similar) to $x^2+y^2=1$, which is circle's equation.

# %%
ce=circle((0,0),1)
c1=circle((0,0),1/1.1,color="red")
c2=circle((0,0),1/1.4,color="green")
c3=circle((0,0),1/1.5,color="yellow")
c4=circle((0,0),1/10,color="cyan")
show(ce+c1+c2+c3+c4,figsize=3,fontsize=4,
frame=True)
# Out:
# Graphics object consisting of 5 graphics primitives

# %% [markdown]
# Now I must explain to you my analyse, Einstein said that $c$ is a speed that can't be overpass. $c$=299792458 m/s. But for me $c$ is not a (only) speed (saying this will make me detested by relativist, I will comment it later) but more a pulsation = $\omega=c=\frac{1}{\sqrt \mu \epsilon}$ and too $\omega=c=\frac{1}{\sqrt LC}$ another way which has been disregard by scientists (only few have investigated it). Now $\omega=c$, no more a speed but an angular frequency (french prefers pulsation). Which provides us with a resonance frequency =$f_r$=$\frac{\omega}{2\pi}$
#
# I am no more limited with a speed ($c$) because this is not a speed (which willn't affect possible tangentiel speed of electron =2c) !
#
# $m_{e}\cdot R\cdot v=\frac{\hbar}{2}\Rightarrow v=\frac{\hbar}{2m_{e}\cdot R}\approx 2\cdot 10^{10}m\cdot s^{-1}$
#
# I created some values which suits better to my calculation.
#
# $L$=  0.00000145915590261650
#
# $\mu$=0.00000125663706143592
#
# $C$=  0.00000000000884194128288307
#
# $\epsilon$=0.00000000000885418781762039

# %%
L=1/n(pi)*360E-8;show("L = ",L);c=299792458
mu=4E-7*n(pi);show("mu=",mu)
C=1/(n(pi)*360E+8);show("C = ",C)
epsilon=1/(mu*c*c);show("epsilon=",epsilon)
# Out:
# 'L = ' 1.14591559026165e-6
# 'mu=' 1.25663706143592e-6
# 'C = ' 8.84194128288307e-12
# 'epsilon=' 8.85418781762039e-12

# %% [markdown]
# So we obtain two different $\omega$ and $c$, I make a difference between the two $c : ç=(v)$, in french we have fortunatly this letter.

# %%
c=1/sqrt(mu*epsilon);print "c=",round(c)
# Out:
# c= 299792458

# %%
nu=1/sqrt(L*C);print u"\u00E7","=",round(nu)
# Out:
# ç = 314159265

# %% [markdown]
# which is $\pi$. But $\pi$ has a singularity at 0E-32 ?
# 3.14159265358979323846264338327950
# written as $\frac{0}{100000000000000000000000000000000}$ ?
#
# $3+\frac{1}{10}$+$\frac{4}{100}$...$\frac{0}{100000000000000000000000000000000}$

# %%
n(pi,digits=33)
# Out:
# 3.14159265358979323846264338327950

# %%
round(3+1/10.0+4/100+1/1000,3)
# Out:
# 3.141

# %% [markdown]
# That's the reason why planck's constant. As he said an electron vibrating with a frequency $f$ could only have an energy of $1 hf, 2 hf, 3 hf, 4 hf, ... $ ; That is,
# energy of vibrating electron = (any integer, except zero) x $hf$. But the electron must possess  at least one quantum of energy for it to vibrate. If it doesn't have at least an energy of $1hf$, it will not vibrate at all and can't produce any light.

# %%
print u"\u00E7","=",round(nu)
# Out:
# ç = 314159265

# %%
print u"\u210F"
# Out:
# ℏ

# %%
hbar=var('hbar',latex_name='\hbar');hbar
# Out:
# hbar
