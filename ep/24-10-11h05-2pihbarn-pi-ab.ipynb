# %% [markdown]
# ###### An de grâce 2018

# %% [markdown]
# Physical interpretation of the Planck’s constant based on the Maxwell theory
# Donald C.Chang

# %% [markdown]
# Son article a attiré mon attention quand j'ai lu qu'il représentait l'énergie de distribution dans un espace de phase elliptique alors que je la represente en cercle.
#
# hk = $\frac {p^2}{a^2}+\frac{q^2}{b^2}=1$
#
# fr = $x^2+y^2=1$

# %%
# %display latex
var("E T V p m w q")
# Out:
# (E, T, V, p, m, w, q)

# %%
ce=circle((0,0),1)
c1=circle((0,0),1/1.1,color="red")
c2=circle((0,0),1/1.2,color="green")
c3=circle((0,0),1/1.5,color="yellow")
c4=circle((0,0),1/10,color="cyan")
show(ce+c1+c2+c3+c4,figsize=3,fontsize=6)
# Out:
# Graphics object consisting of 5 graphics primitives

# %%
var("a b E h nu")
E0=E==h*nu;show(E0)
# Out:
# E == h*nu

# %% [markdown]
# $\sigma _{x}=\begin{pmatrix} 0&1 \\ 1& 0\end{pmatrix},\sigma _{y}=\begin{pmatrix} 0&-i \\ i& 0\end{pmatrix}, \sigma _{z}=\begin{pmatrix} 1&0 \\ 0& -1\end{pmatrix}$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $\lambda = \frac{c}{\nu} = 2\pi R \Rightarrow R = \frac{c}{2\pi \nu}$
# $S = \frac{E}{c}\cdot R = \frac{h\nu}{c}\cdot \frac{c}{2\pi \nu} \Rightarrow L = \frac{h}{2\pi} = \hbar$
#
# ![image.png](attachment:image.png)
#
# $\hat S_z\left|-1\right> = -\hbar \left|-1\right>$

# %% [markdown]
# ![image.png](attachment:image.png)
#
# $\hat S_z=+\hbar$

# %% [markdown]
# ![image.png](attachment:image.png)
#
# $\hat S_z\left|0\right> = 0$

# %% [markdown]
# $m_{e}\cdot R\cdot v=\frac{\hbar}{2}\Rightarrow v=\frac{\hbar}{2m_{e}\cdot R}\approx 2\cdot 10^{10}m\cdot s^{-1}$
#
# $\vec {J} = \vec {L} + \vec {S}$

# %% [markdown]
# $\left\{\begin{matrix} k=4\pi ^{2}\cdot m\cdot \nu _{0}^{2}\\v=2\pi r\cdot \nu \end{matrix}\right.\Rightarrow \frac{m\cdot v^{2}}{r}=k\cdot r+e\cdot v\cdot B\Rightarrow \nu \approx \nu _{0}\pm \frac{e\cdot B}{4\pi m}$
